# %% [markdown]
# # Exploratory data analysis
# ## openfoodfacts + USDA database

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset: the paths depend on the path of the unzipped data 'food_dbs.zip'
# adjust the paths as necessary, default - as below - assumes the data is in the same directory as this notebook
df_off = pd.read_csv('processed/off_nutrition_clean.csv')
df_usda =pd.read_csv('processed/usda_nutrition_clean.csv')
# Out:
# /var/folders/yz/grwlw1c90b1dbggwlxd8jf200000gn/T/ipykernel_64829/3688150373.py:6: DtypeWarning: Columns (0: item_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_off = pd.read_csv('processed/off_nutrition_clean.csv')
# /var/folders/yz/grwlw1c90b1dbggwlxd8jf200000gn/T/ipykernel_64829/3688150373.py:7: DtypeWarning: Columns (0: portion_description) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_usda =pd.read_csv('processed/usda_nutrition_clean.csv')

# %%
df_off.columns
# Out:
# Index(['item_id', 'item_name', 'brand', 'kcal_100g', 'protein_100g',
#        'carbs_100g', 'fat_100g', 'serving_size', 'quantity', 'source'],
#       dtype='str')

# %%
df_usda.columns
# Out:
# Index(['item_id', 'item_name', 'brand', 'kcal_100g', 'protein_100g',
#        'carbs_100g', 'fat_100g', 'portion_description', 'gram_weight',
#        'source'],
#       dtype='str')

# %%
df_off.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 66341 entries, 0 to 66340
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   item_id       66341 non-null  object
#  1   item_name     66341 non-null  str
#  2   brand         56777 non-null  str
#  3   kcal_100g     66341 non-null  float64
#  4   protein_100g  66341 non-null  float64
#  5   carbs_100g    66341 non-null  float64
#  6   fat_100g      66341 non-null  float64
#  7   serving_size  47711 non-null  str
#  8   quantity      27935 non-null  str
#  9   source        66341 non-null  str
# dtypes: float64(4), object(1), str(5)
# memory usage: 5.1+ MB

# %%
df_usda.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1817628 entries, 0 to 1817627
# Data columns (total 10 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   item_id              int64
#  1   item_name            str
#  2   brand                float64
#  3   kcal_100g            float64
#  4   protein_100g         float64
#  5   carbs_100g           float64
#  6   fat_100g             float64
#  7   portion_description  str
#  8   gram_weight          float64
#  9   source               str
# dtypes: float64(6), int64(1), str(3)
# memory usage: 138.7 MB

# %%
print(df_usda.gram_weight.isna().sum())
print(df_usda.portion_description.isna().sum())
# Out:
# 1804600
# 1804656

# %%
# sum of the NAN per column of df_usda
print(df_usda.isna().sum())
# Out:
# item_id                      0
# item_name                    0
# brand                  1817628
# kcal_100g                    0
# protein_100g                 0
# carbs_100g                   0
# fat_100g                     0
# portion_description    1804656
# gram_weight            1804600
# source                       0
# dtype: int64

# %%
df_usda.describe()
# Out:
#             item_id  brand     kcal_100g  protein_100g    carbs_100g  \
# count  1.817628e+06    0.0  1.817628e+06  1.817628e+06  1.817628e+06
# mean   1.617401e+06    NaN  2.672501e+02  7.458632e+00  3.307498e+01
# std    6.986552e+05    NaN  1.850154e+02  8.957361e+00  2.906477e+01
# min    1.675120e+05    NaN  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.130349e+06    NaN  9.100000e+01  7.100000e-01  6.670000e+00
# 50%    1.677964e+06    NaN  2.670000e+02  4.760000e+00  2.333000e+01
# 75%    2.176503e+06    NaN  4.000000e+02  1.064000e+01  5.962000e+01
# max    2.747651e+06    NaN  9.000000e+02  1.000000e+02  1.000000e+02
#
#            fat_100g   gram_weight
# count  1.817628e+06  13028.000000
# mean   1.220373e+01    237.026819
# std    1.616996e+01    317.012038
# min    0.000000e+00      0.100000
# 25%    0.000000e+00     85.000000
# 50%    5.560000e+00    170.000000
# 75%    1.940000e+01    250.000000
# max    1.000000e+02   6000.000000

# %%
df_usda_clean = df_usda.drop(columns=['gram_weight', 'portion_description'])

# %%
df_usda_clean.item_name('EGG')
# Out:
#    item_id                                   item_name  brand  kcal_100g  \
# 0  1251280                     PARMESAN PEPPERCORN DIP    NaN      188.0
# 1  1251668                     STAR WARS HOT COCOA MIX    NaN      393.0
# 2  1251760           GOOD MEADOW, CLASSIC COCONUT CAKE    NaN      395.0
# 3  1251788                        SOURDOUGH MULTIGRAIN    NaN      246.0
# 4  1252048  REDUCED SODIUM CHICKEN BROTH, RICH CHICKEN    NaN        6.0
#
#    protein_100g  carbs_100g  fat_100g source
# 0         12.50        6.25     15.62   usda
# 1          0.00       96.43      0.00   usda
# 2          2.63       59.21     17.11   usda
# 3          7.02       47.37      1.75   usda
# 4          1.25        0.42      0.00   usda
